# %%
class Item:
    def __init__(self):
        print("I am created")
    def calculate_total_price(self,x,y):
        return x*y

item1=Item()
item1.name="Phone.."
item1.price=100
item1.quantity=5
ok=item1.calculate_total_price(item1.price,item1.quantity)
print(ok)

item2=Item()
item2.name="Phone Mobile.."
item2.price=200
item2.quantity=7
ok1=item2.calculate_total_price(item2.price,item2.quantity)
print(ok1)
# Out:
# I am created
# 500
# I am created
# 1400

# %%
class Item:
    pay_rate=0.8
    def __init__(self,name:str,price:float,quantity):
        assert price>=0, f"Price {price} is not greater than or equal to zero!!"
        assert quantity>=0, f"Quantity {quantity} is not greater or equal to zero!!"
        self.name=name 
        self.price=price
        self.quantity=quantity
        
    def calculate_total_price(self):
        return self.price*self.quantity

item1=Item("Phone",100,4)
item2=Item("Laptop",1000,10)

item1.has_numpad=False
print(item1.calculate_total_price())
print(item2.calculate_total_price())
print(Item.pay_rate)
print(item1.pay_rate)
print(item2.pay_rate)

print(Item.__dict__)
# Out:
# 400
# 10000
# 0.8
# 0.8
# 0.8
# {'__module__': '__main__', 'pay_rate': 0.8, '__init__': <function Item.__init__ at 0x7fb9b679d1f0>, 'calculate_total_price': <function Item.calculate_total_price at 0x7fb9b679d040>, '__dict__': <attribute '__dict__' of 'Item' objects>, '__weakref__': <attribute '__weakref__' of 'Item' objects>, '__doc__': None}

# %%
class Item:
    pay_rate=0.8
    al=[]
    def __init__(self,name:str,price:float,quantity):
        assert price>=0, f"Price {price} is not greater than or equal to zero!!"
        assert quantity>=0, f"Quantity {quantity} is not greater or equal to zero!!"
        self.name=name 
        self.price=price
        self.quantity=quantity
        
        Item.al.append(self)
        
    def calculate_total_price(self):
        return self.price*self.quantity
    
    def apply_discount(self):
        self.price=self.price*self.pay_rate
        
    def __repr__(self):
        return f"Item('{self.name}',{self.price},{self.quantity})"
        
item1 = Item("Phone", 100, 1)
item2 = Item("Laptop", 1000, 3)
item3 = Item("Cable", 10, 5)
item4 = Item("Mouse", 50, 5)
item5 = Item("Keyboard", 75, 5)

print(Item.al)

for instance in Item.al:
    print(instance.name)
# Out:
# [Item('Phone',100,1), Item('Laptop',1000,3), Item('Cable',10,5), Item('Mouse',50,5), Item('Keyboard',75,5)]
# Phone
# Laptop
# Cable
# Mouse
# Keyboard

# %%
import csv

class Item:
    pay_rate=0.8
    al=[]
    def __init__(self,name:str,price:float,quantity):
#         assert price>=0, f"Price {price} is not greater than or equal to zero!!"
#         assert quantity>=0, f"Quantity {quantity} is not greater or equal to zero!!"
        self.name=name 
        self.price=price
        self.quantity=quantity
        
        Item.al.append(self)
        
    def calculate_total_price(self):
        return self.price*self.quantity
    
    def apply_discount(self):
        self.price=self.price*self.pay_rate
        
    def __repr__(self):
        return f"Item('{self.name}',{self.price},{self.quantity})"
    
    @classmethod
    def instantiate_from_csv(cls):
        with open("item.csv","r") as f:
            reader = csv.DictReader(f)
            items=list(reader)
        
        for item in items:
            Item(
                name=item.get("name"),
                price=int(item.get("price")),
                quantity=int(item.get("quantity")),
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num,float):
            return num.is_integer()
        elif isinstance(num,int):
            return True
        else:
            return False
            
        
    
# Item.instantiate_from_csv()       #@classmethod
# print(Item.al)


print(Item.is_integer(7.0))           #@staticmethod
# Out:
# True

# %%
# Inheritance

import csv

class Item:
    pay_rate=0.8
    al=[]
    def __init__(self,name:str,price:float,quantity):
        assert price>=0, f"Price {price} is not greater than or equal to zero!!"
        assert quantity>=0, f"Quantity {quantity} is not greater or equal to zero!!"
        self.name=name 
        self.price=price
        self.quantity=quantity
        
        Item.al.append(self)
        
    def calculate_total_price(self):
        return self.price*self.quantity
    
    def apply_discount(self):
        self.price=self.price*self.pay_rate
        
    def __repr__(self):
        return f"{self.__class__.__name__}('{self.name}',{self.price},{self.quantity})"
    
    @classmethod
    def instantiate_from_csv(cls):
        with open("item.csv","r") as f:
            reader = csv.DictReader(f)
            items=list(reader)
        
        for item in items:
            Item(
                name=item.get("name"),
                price=int(item.get("price")),
                quantity=int(item.get("quantity")),
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num,float):
            return num.is_integer()
        elif isinstance(num,int):
            return True
        else:
            return False

class Phone(Item):
    def __init__(self,name:str,price:float,quantity,broken_phones=0):
        super().__init__(name, price,quantity)
        
        assert broken_phones>=0, f"Broken Phones {quantity} is not greater or equal to zero!!"
        
        self.broken_phones=broken_phones    
        
phone1=Phone("Iphone13",500,4)
print(phone1.calculate_total_price())
# phone1.broken_phones=1
phone2=Phone("Ihpone12",400,10)
# phone2.broken_phones=4

print(Item.al)
print(Phone.al)
# Out:
# 2000
# [Phone('Iphone13',500,4), Phone('Ihpone12',400,10)]
# [Phone('Iphone13',500,4), Phone('Ihpone12',400,10)]

# %%
# Inheritance

import csv

class Item:
    pay_rate=0.8
    al=[]
    def __init__(self,name:str,price:float,quantity):
        assert price>=0, f"Price {price} is not greater than or equal to zero!!"
        assert quantity>=0, f"Quantity {quantity} is not greater or equal to zero!!"
        self.__name=name                # it's is a type of encapsulation
        self.price=price
        self.quantity=quantity
        
        Item.al.append(self)
        
    def calculate_total_price(self):
        return self.price*self.quantity
    
    def apply_discount(self):
        self.price=self.price*self.pay_rate
        
    def __repr__(self):
        return f"{self.__class__.__name__}('{self.name}',{self.price},{self.quantity})"
    
    @property
    def name(self):
        return self.__name
    
    @name.setter
    def name(self,value):
        print("you are trying to set")
        if len(value)>10:
            raise Exception("The name is too long!!")
        else:
            self.__name=value
    
    @classmethod
    def instantiate_from_csv(cls):
        with open("item.csv","r") as f:
            reader = csv.DictReader(f)
            items=list(reader)
        
        for item in items:
            Item(
                name=item.get("name"),
                price=int(item.get("price")),
                quantity=int(item.get("quantity")),
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num,float):
            return num.is_integer()
        elif isinstance(num,int):
            return True
        else:
            return False
        
#     @property
#     def read_only_name(self):
#         return "AAA"
    
    


class Phone(Item):
    def __init__(self,name:str,price:float,quantity,broken_phones=0):
        super().__init__(name, price,quantity)
        
        assert broken_phones>=0, f"Broken Phones {quantity} is not greater or equal to zero!!"
        
        self.broken_phones=broken_phones    

        
item1=Item("MyItem",750,10)
# item1.name="OtherItem"

# print(item1.read_only_name)

# item1.read_only_name="BBB"

item1.name="OtherItem"
item1.price=900
print(item1.name)
# Out:
# you are trying to set
# 900
# OtherItem

# %%
# Ploymorphism

name="Jim"
print(len(name))

names=["Sachin","Kaka","Malik"]
print(len(names))
# Out:
# 3
# 3
