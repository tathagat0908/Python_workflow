# %%
arr=[2,3,1,5,1]
arr[0],arr[2]=arr[2],arr[0]
print(arr)
# Out:
# [1, 3, 2, 5, 1]

# %%
arr=[2,3,1,5,1]
i=0
while i<len(arr):
    if arr[i]==i+1:
        i+=1
    else:
        print(arr)
        arr[i],arr[arr[i]-1]=arr[arr[i]-1],arr[i]
print(arr)
# Out:
# [2, 3, 1, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# [3, 3, 2, 5, 1]
# [2, 3, 2, 5, 1]
# ...

# %%
arr=[2,3,2,5,1]
i=0
while(i<len(arr)):
    p=arr[i]
    if(arr[i]==i+1):
        i+=1
    elif(arr[p-1]==p):
        break
    else:
        c=arr[i]
        arr[i]=arr[c-1]
        arr[c-1]=c
print("missing nu",i+1)
print("duplicate nu",arr[i])
print(arr)
# Out:
# missing nu 1
# duplicate nu 2
# [2, 2, 3, 5, 1]
